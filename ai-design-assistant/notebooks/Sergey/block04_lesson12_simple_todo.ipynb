# %% [markdown]
# # Блок 4 — Занятие 12 — Матрицы
#
# Матрица — это таблица чисел.
# В машинном обучении матрица часто описывает данные: строки — объекты, столбцы — признаки.
# На уроке:
# 1. создаём матрицу
# 2. смотрим её размер
# 3. создаём вектор
# 4. умножаем матрицу на вектор
# 5. делаем вывод
#
# Формат урока: **5 кодовых ячеек**, одна ячейка = одна простая идея.

# %% [markdown]
# ## Ячейка 1 — создаём матрицу
#
# Матрица — это просто двумерный массив чисел.

# %%
# TODO: напишите решение сами
import numpy as np

X = np.array([
    [16, 22],
    [23, 10],
    [3, 16]
])

print(X)
assert X.shape == (3, 2)
# Out:
# [[16 22]
#  [23 10]
#  [ 3 16]]

# %% [markdown]
# ## Ячейка 2 — размер матрицы
#
# Свойство `.shape` показывает число строк и столбцов.

# %%
# TODO: напишите решение сами
rows, cols = X.shape
print("Строк:", rows)
print("Столбцов:", cols)

assert rows == 3
assert cols == 2
# Out:
# Строк: 3
# Столбцов: 2

# %% [markdown]
# ## Ячейка 3 — создаём вектор
#
# Этот вектор будет умножаться на матрицу.

# %%
# TODO: напишите решение сами
w = np.array([30, 10])
print("Вектор w:", w)

assert len(w) == 2
# Out:
# Вектор w: [30 10]

# %% [markdown]
# ## Ячейка 4 — умножение
#
# Используем оператор `@`. Это матричное умножение.

# %%
# TODO: напишите решение сами
result = X @ w
print("Результат умножения:", result)

assert len(result) == 3
# Out:
# Результат умножения: [700 790 250]

# %% [markdown]
# ## Ячейка 5 — вывод
#
# Матрица помогает сразу обрабатывать много объектов.

# %%
# TODO: напишите решение сами
print("Каждая строка матрицы умножилась на вектор.")
print("Так в ML часто считают значения для всех объектов сразу.")

assert isinstance(result, np.ndarray)
# Out:
# Каждая строка матрицы умножилась на вектор.
# Так в ML часто считают значения для всех объектов сразу.
